# %%
from google.colab import drive
drive.mount('/content/drive')
import os

# 指定 ZIP 檔案路徑和解壓縮目標資料夾
zip_file_path = "/content/drive/MyDrive/nycu-i-al-i-ml-2024-seq-2-seq-and-attention.zip"
output_folder = "/content/unzipped_files"

# 3. 創建解壓縮資料夾 (如果不存在)
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 4. 解壓縮 ZIP 檔案
# !unzip -o "$zip_file_path" -d "$output_folder"

# 5. 確認解壓縮結果
print(f"ZIP 檔案已解壓縮至：{output_folder}")
print("檔案列表：")
# !ls "$output_folder"
# Out:
# Mounted at /content/drive
# Archive:  /content/drive/MyDrive/nycu-i-al-i-ml-2024-seq-2-seq-and-attention.zip
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/lexicon.txt
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/sample.csv
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/1.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/10.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/100.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/101.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/102.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/103.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/104.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/105.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/106.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/107.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/108.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/109.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/11.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/110.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/111.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/112.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/113.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/114.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/115.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/116.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/117.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/118.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/119.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/12.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/120.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/121.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/122.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/123.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/124.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/125.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/126.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/127.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/128.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/129.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/13.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/130.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/131.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/132.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/133.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/134.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/135.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/136.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/137.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/138.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/139.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/14.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/140.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/141.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/142.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/143.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/144.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/145.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/146.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/147.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/148.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/149.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/15.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/150.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/151.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/152.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/153.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/154.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/155.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/156.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/157.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/158.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/159.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/16.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/160.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/161.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/162.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/163.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/164.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/165.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/166.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/167.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/168.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/169.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/17.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/170.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/171.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/172.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/173.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/174.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/175.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/176.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/177.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/178.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/179.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/18.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/180.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/181.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/182.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/183.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/184.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/185.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/186.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/187.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/188.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/189.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/19.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/190.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/191.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/192.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/193.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/194.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/195.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/196.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/197.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/198.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/199.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/2.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/20.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/200.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/201.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/202.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/203.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/204.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/205.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/206.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/207.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/208.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/209.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/21.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/210.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/211.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/212.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/213.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/214.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/215.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/216.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/217.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/218.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/219.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/22.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/220.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/221.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/222.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/223.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/224.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/225.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/226.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/227.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/228.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/229.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/23.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/230.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/231.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/232.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/233.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/234.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/235.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/236.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/237.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/238.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/239.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/24.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/240.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/241.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/242.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/243.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/244.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/245.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/246.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/247.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/248.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/249.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/25.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/250.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/251.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/252.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/253.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/254.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/255.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/256.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/257.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/258.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/259.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/26.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/260.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/261.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/262.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/263.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/264.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/265.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/266.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/267.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/268.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/269.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/27.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/270.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/271.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/272.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/273.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/274.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/275.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/276.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/277.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/278.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/279.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/28.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/280.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/281.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/282.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/283.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/284.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/285.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/286.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/287.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/288.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/289.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/29.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/290.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/291.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/292.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/293.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/294.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/295.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/296.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/297.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/298.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/299.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/3.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/30.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/300.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/301.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/302.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/303.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/304.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/305.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/306.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/307.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/308.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/309.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/31.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/310.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/311.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/312.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/313.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/314.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/315.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/316.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/317.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/318.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/319.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/32.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/320.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/321.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/322.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/323.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/324.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/325.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/326.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/327.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/328.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/329.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/33.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/330.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/331.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/332.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/333.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/334.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/335.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/336.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/337.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/338.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/339.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/34.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/340.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/341.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/342.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/343.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/344.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/345.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/346.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/35.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/36.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/37.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/38.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/39.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/4.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/40.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/41.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/42.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/43.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/44.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/45.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/46.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/47.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/48.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/49.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/5.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/50.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/51.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/52.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/53.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/54.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/55.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/56.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/57.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/58.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/59.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/6.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/60.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/61.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/62.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/63.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/64.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/65.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/66.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/67.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/68.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/69.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/7.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/70.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/71.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/72.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/73.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/74.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/75.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/76.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/77.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/78.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/79.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/8.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/80.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/81.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/82.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/83.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/84.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/85.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/86.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/87.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/88.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/89.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/9.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/90.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/91.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/92.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/93.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/94.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/95.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/96.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/97.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/98.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/test/99.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train-toneless.csv
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train.csv
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/10.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/100.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1000.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1001.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1002.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1003.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1004.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1005.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1006.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1007.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1008.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1009.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/101.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1010.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1011.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1012.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1013.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1014.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1015.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1016.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1017.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1018.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1019.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/102.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1020.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1021.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1022.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1023.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1024.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1025.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1026.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1027.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1028.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1029.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/103.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1030.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1031.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1032.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1033.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1034.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1035.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1036.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1037.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1038.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1039.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/104.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1040.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1041.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1042.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1043.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1044.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1045.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1046.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1047.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1048.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1049.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/105.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1050.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1051.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1052.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1053.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1054.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1055.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1056.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1057.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1058.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1059.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/106.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1060.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1061.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1062.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1063.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1064.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1065.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1066.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1067.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1068.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1069.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/107.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1070.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1071.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1072.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1073.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1074.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1075.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1076.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1077.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1078.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1079.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/108.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1080.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1081.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1082.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1083.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1084.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1085.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1086.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1087.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1088.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1089.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/109.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1090.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1091.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1092.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1093.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1094.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1095.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1096.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1097.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1098.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1099.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/11.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/110.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1100.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1101.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1102.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1103.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1104.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1105.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1106.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1107.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1108.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1109.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/111.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1110.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1111.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1112.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1113.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1114.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1115.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1116.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1117.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1118.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1119.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/112.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1120.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1121.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1122.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1123.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1124.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1125.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1126.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1127.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1128.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1129.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/113.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1130.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1131.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1132.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1133.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1134.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1135.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1136.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1137.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1138.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1139.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/114.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1140.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1141.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1142.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1143.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1144.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1145.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1146.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1147.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1148.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1149.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/115.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1150.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1151.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1152.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1153.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1154.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1155.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1156.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1157.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1158.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1159.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/116.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1160.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1161.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1162.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1163.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1164.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1165.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1166.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1167.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1168.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1169.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/117.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1170.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1171.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1172.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1173.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1174.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1175.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1176.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1177.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1178.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1179.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/118.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1180.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1181.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1182.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1183.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1184.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1185.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1186.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1187.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1188.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1189.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/119.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1190.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1191.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1192.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1193.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1194.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1195.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1196.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1197.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1198.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1199.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/12.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/120.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1200.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1201.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1202.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1203.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1204.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1205.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1206.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1207.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1208.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1209.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/121.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1210.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1211.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1212.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1213.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1214.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1215.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1216.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1217.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1218.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1219.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/122.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1220.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1221.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1222.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1223.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1224.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1225.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1226.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1227.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1228.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1229.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/123.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1230.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1231.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1232.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1233.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1234.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1235.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1236.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1237.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1238.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1239.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/124.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1240.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1241.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1242.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1243.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1244.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1245.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1246.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1247.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1248.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1249.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/125.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1250.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1251.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1252.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1253.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1254.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1255.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1256.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1257.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1258.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1259.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/126.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1260.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1261.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1262.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1263.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1264.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1265.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1266.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1267.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1268.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1269.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/127.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1270.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1271.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1272.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1273.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1274.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/1275.wav
# ...
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/802.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/803.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/804.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/805.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/806.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/807.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/808.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/809.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/81.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/810.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/811.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/812.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/813.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/814.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/815.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/816.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/817.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/818.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/819.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/82.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/820.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/821.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/822.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/823.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/824.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/825.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/826.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/827.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/828.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/829.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/83.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/830.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/831.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/832.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/833.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/834.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/835.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/836.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/837.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/838.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/839.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/84.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/840.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/841.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/842.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/843.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/844.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/845.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/846.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/847.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/848.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/849.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/85.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/850.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/851.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/852.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/853.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/854.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/855.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/856.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/857.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/858.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/859.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/86.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/860.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/861.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/862.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/863.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/864.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/865.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/866.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/867.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/868.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/869.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/87.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/870.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/871.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/872.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/873.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/874.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/875.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/876.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/877.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/878.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/879.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/88.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/880.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/881.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/882.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/883.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/884.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/885.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/886.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/887.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/888.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/889.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/89.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/890.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/891.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/892.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/893.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/894.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/895.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/896.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/897.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/898.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/899.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/9.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/90.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/900.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/901.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/902.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/903.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/904.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/905.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/906.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/907.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/908.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/909.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/91.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/910.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/911.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/912.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/913.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/914.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/915.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/916.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/917.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/918.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/919.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/92.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/920.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/921.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/922.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/923.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/924.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/925.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/926.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/927.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/928.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/929.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/93.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/930.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/931.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/932.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/933.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/934.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/935.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/936.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/937.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/938.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/939.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/94.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/940.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/941.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/942.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/943.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/944.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/945.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/946.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/947.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/948.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/949.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/95.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/950.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/951.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/952.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/953.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/954.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/955.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/956.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/957.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/958.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/959.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/96.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/960.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/961.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/962.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/963.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/964.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/965.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/966.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/967.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/968.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/969.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/97.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/970.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/971.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/972.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/973.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/974.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/975.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/976.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/977.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/978.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/979.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/98.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/980.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/981.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/982.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/983.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/984.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/985.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/986.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/987.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/988.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/989.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/99.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/990.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/991.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/992.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/993.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/994.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/995.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/996.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/997.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/998.wav
#   inflating: /content/unzipped_files/kaldi-taiwanese-asr/train/999.wav
# ZIP 檔案已解壓縮至：/content/unzipped_files
# 檔案列表：
# kaldi-taiwanese-asr

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.optim as optim
import torch.nn.functional as F
import torchaudio
import numpy as np
from sklearn.model_selection import train_test_split
# !pip install torchaudio torch comet-ml

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.optim as optim
import torch.nn.functional as F
import torchaudio
import numpy as np
from sklearn.model_selection import train_test_split

##########################
# 1. Lexicon & TextTransform
##########################

def parse_lexicon(lexicon_path):
    """
    Parse the lexicon.txt file and build a phoneme_map dict.
    This is the same as your original code.
    """
    phoneme_map = {}
    index = 0
    with open(lexicon_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            phoneme = parts[0]
            if phoneme not in phoneme_map:
                phoneme_map[phoneme] = index
                index += 1
    # Add <SPACE> to the map
    phoneme_map['<SPACE>'] = index
    return phoneme_map

class TextTransform:
    """
    Same as your original code (with minor clarifications).
    """
    def __init__(self, lexicon_path):
        self.phoneme_map = parse_lexicon(lexicon_path)
        self.index_map = {v: k for k, v in self.phoneme_map.items()}
        # Ensure that the blank label index is the largest
        self.blank_label = max(self.index_map.keys())

    def text_to_int(self, text):
        int_sequence = []
        phonemes = text.split()  # Split by spaces
        for phoneme in phonemes:
            if phoneme in self.phoneme_map:
                int_sequence.append(self.phoneme_map[phoneme])
        return int_sequence

    def int_to_text(self, labels):
        string = []
        for i in labels:
            if i == self.blank_label:
                # blank symbol
                string.append('')
            elif i in self.index_map:
                string.append(self.index_map[i])
        # Join with space
        return ' '.join([s for s in string if s != ''])


##########################
# 2. Audio Transforms (same as original)
##########################

train_audio_transforms = nn.Sequential(
    torchaudio.transforms.MelSpectrogram(sample_rate=16000, n_mels=128),
    torchaudio.transforms.FrequencyMasking(freq_mask_param=15),
    torchaudio.transforms.TimeMasking(time_mask_param=35)
)

valid_audio_transforms = torchaudio.transforms.MelSpectrogram(sample_rate=16000, n_mels=128)


##########################
# (NEW) 2A. Custom Dataset
##########################

class TaiwaneseDataset(data.Dataset):
    """
    A custom Dataset that:
      - Expects a dataframe with columns 'id', 'text'
      - Loads the corresponding WAV from the appropriate folder
      - Applies the specified audio transforms
      - Converts the transcript to an integer sequence

    If 'subset' == 'test', it will read files from 'test' folder and produce dummy labels.
    """
    def __init__(self, dataframe, data_path, text_transform, audio_transforms=None, subset='train'):
        self.dataframe = dataframe.reset_index(drop=True)
        self.data_path = data_path
        self.text_transform = text_transform
        self.audio_transforms = audio_transforms
        self.subset = subset

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        # Retrieve row
        row = self.dataframe.iloc[idx]
        file_id = str(row["id"])

        # For training/valid sets, there's a 'text' column in row
        utterance = row["text"] if "text" in row else ""

        # Depending on subset, pick the folder
        folder_name = 'train' if self.subset != 'test' else 'test'
        audio_file_path = os.path.join(self.data_path, folder_name, file_id + ".wav")

        # Load waveform
        waveform, sr = torchaudio.load(audio_file_path)

        # Apply transforms
        if self.audio_transforms is not None:
            spec = self.audio_transforms(waveform).squeeze(0).transpose(0, 1)
        else:
            # default MelSpectrogram if not provided
            spec = torchaudio.transforms.MelSpectrogram(sample_rate=16000, n_mels=128)(waveform)
            spec = spec.squeeze(0).transpose(0, 1)

        if self.subset != 'test':
            # we have labels
            label = torch.Tensor(self.text_transform.text_to_int(utterance))
            # input_length depends on how your CNN reduces time dimension
            input_length = spec.shape[0] // 2
            label_length = len(label)
        else:
            # For test set, we might not have 'text'
            label = torch.tensor([0], dtype=torch.long)
            input_length = spec.shape[0] // 2
            label_length = 1

        return spec, label, input_length, label_length


##########################
# (NEW) 2B. Custom Collate Fn
##########################

def taiwanese_collate_fn(batch):
    """
    Collate function to handle padding of variable-length spectrograms and labels.

    batch: List of tuples (spec, label, input_len, label_len)
    """
    specs = [b[0] for b in batch]
    labels = [b[1] for b in batch]
    input_lengths = [b[2] for b in batch]
    label_lengths = [b[3] for b in batch]

    # Pad spectrograms to the max time dimension in the batch
    specs = nn.utils.rnn.pad_sequence(specs, batch_first=True)
    specs = specs.unsqueeze(1).transpose(2,3)  # (batch, 1, n_mels, time)

    # Pad labels
    labels = nn.utils.rnn.pad_sequence(labels, batch_first=True)

    return specs, labels, input_lengths, label_lengths


##########################
# 3. Model (DeepSpeech2)
# [No changes from your original code, except we keep them here for completeness]
##########################

class CNNLayerNorm(nn.Module):
    """Layer normalization built for CNNs input"""
    def __init__(self, n_feats):
        super(CNNLayerNorm, self).__init__()
        self.layer_norm = nn.LayerNorm(n_feats)

    def forward(self, x):
        # x (batch, channel, feature, time)
        x = x.transpose(2, 3).contiguous() # (batch, channel, time, feature)
        x = self.layer_norm(x)
        return x.transpose(2, 3).contiguous() # (batch, channel, feature, time)

class ResidualCNN(nn.Module):
    """Residual CNN with Layer Norm + GELU"""
    def __init__(self, in_channels, out_channels, kernel, stride, dropout, n_feats):
        super(ResidualCNN, self).__init__()
        self.cnn1 = nn.Conv2d(in_channels, out_channels, kernel, stride, padding=kernel//2)
        self.cnn2 = nn.Conv2d(out_channels, out_channels, kernel, stride, padding=kernel//2)
        self.dropout1 = nn.Dropout(dropout)
        self.dropout2 = nn.Dropout(dropout)
        self.layer_norm1 = CNNLayerNorm(n_feats)
        self.layer_norm2 = CNNLayerNorm(n_feats)

    def forward(self, x):
        residual = x  # (batch, channel, feature, time)
        x = self.layer_norm1(x)
        x = F.gelu(x)
        x = self.dropout1(x)
        x = self.cnn1(x)

        x = self.layer_norm2(x)
        x = F.gelu(x)
        x = self.dropout2(x)
        x = self.cnn2(x)
        x += residual
        return x

class BidirectionalGRU(nn.Module):
    def __init__(self, rnn_dim, hidden_size, dropout, batch_first):
        super(BidirectionalGRU, self).__init__()
        self.BiGRU = nn.GRU(
            input_size=rnn_dim, hidden_size=hidden_size,
            num_layers=1, batch_first=batch_first, bidirectional=True
        )
        self.layer_norm = nn.LayerNorm(rnn_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.layer_norm(x)
        x = F.gelu(x)
        x, _ = self.BiGRU(x)
        x = self.dropout(x)
        return x

class SpeechRecognitionModel(nn.Module):
    def __init__(self, n_cnn_layers, n_rnn_layers, rnn_dim, n_class, n_feats, stride=2, dropout=0.1):
        super(SpeechRecognitionModel, self).__init__()
        n_feats = n_feats // 2
        self.cnn = nn.Conv2d(1, 32, 3, stride=stride, padding=3//2)

        # n residual cnn layers with filter size of 32
        self.rescnn_layers = nn.Sequential(*[
            ResidualCNN(32, 32, kernel=3, stride=1, dropout=dropout, n_feats=n_feats)
            for _ in range(n_cnn_layers)
        ])
        self.fully_connected = nn.Linear(n_feats*32, rnn_dim)

        self.birnn_layers = nn.Sequential(*[
            BidirectionalGRU(
                rnn_dim=rnn_dim if i==0 else rnn_dim*2,
                hidden_size=rnn_dim, dropout=dropout, batch_first=i==0
            )
            for i in range(n_rnn_layers)
        ])

        self.classifier = nn.Sequential(
            nn.Linear(rnn_dim*2, rnn_dim),  # birnn returns rnn_dim*2
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(rnn_dim, n_class)
        )

    def forward(self, x):
        x = self.cnn(x)
        x = self.rescnn_layers(x)
        sizes = x.size()
        x = x.view(sizes[0], sizes[1] * sizes[2], sizes[3])  # (batch, feature, time)
        x = x.transpose(1, 2) # (batch, time, feature)
        x = self.fully_connected(x)
        x = self.birnn_layers(x)
        x = self.classifier(x)
        return x


##########################
# 4. Training / Validation routines
# [No major changes except that we do not call data_processing inside the loop]
##########################

def train(model, device, train_loader, criterion, optimizer, scheduler, epoch, iter_meter):
    model.train()
    data_len = len(train_loader.dataset)
    for batch_idx, _data in enumerate(train_loader):
        spectrograms, labels, input_lengths, label_lengths = _data
        spectrograms, labels = spectrograms.to(device), labels.to(device)
        # input_lengths and label_lengths typically must be on CPU or long dtype, depending on PyTorch version:
        input_lengths = torch.tensor(input_lengths, dtype=torch.long)
        label_lengths = torch.tensor(label_lengths, dtype=torch.long)

        optimizer.zero_grad()
        output = model(spectrograms)
        # for CTC: (time, batch, n_class)
        output = F.log_softmax(output, dim=2).transpose(0, 1)

        loss = criterion(output, labels, input_lengths, label_lengths)
        loss.backward()

        optimizer.step()
        scheduler.step()
        iter_meter.step()

        if batch_idx % 100 == 0 or batch_idx == len(train_loader) - 1:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, (batch_idx + 1) * len(spectrograms), data_len,
                100. * (batch_idx + 1) / len(train_loader), loss.item()))

def validate(model, device, val_loader, criterion, iter_meter, text_transform):
    model.eval()
    val_loss = 0
    val_wer = []
    val_lev_dist = []
    with torch.no_grad():
        for batch_idx, _data in enumerate(val_loader):
            spectrograms, labels, input_lengths, label_lengths = _data
            spectrograms, labels = spectrograms.to(device), labels.to(device)
            input_lengths = torch.tensor(input_lengths, dtype=torch.long)
            label_lengths = torch.tensor(label_lengths, dtype=torch.long)

            output = model(spectrograms)
            output = F.log_softmax(output, dim=2).transpose(0, 1)

            loss = criterion(output, labels, input_lengths, label_lengths)
            val_loss += loss.item()

            decoded_preds, decoded_targets = GreedyDecoder(
                output.transpose(0, 1), labels, label_lengths,
                text_transform=text_transform, blank_label=text_transform.blank_label
            )
            for j in range(len(decoded_preds)):
                val_wer.append(wer(decoded_targets[j], decoded_preds[j]))
                val_lev_dist.append(levenshtein_distance(decoded_targets[j], decoded_preds[j]))

    avg_val_loss = val_loss / len(val_loader)
    avg_val_wer = sum(val_wer) / len(val_wer) if len(val_wer) > 0 else 0
    avg_val_lev_dist = sum(val_lev_dist) / len(val_lev_dist) if len(val_lev_dist) > 0 else 0

    print('Validation set: Average loss: {:.4f}, Average WER: {:.4f}, Average Levenshtein Distance: {:.4f}\n'.format(
        avg_val_loss, avg_val_wer, avg_val_lev_dist))

    return avg_val_loss, avg_val_wer, avg_val_lev_dist


##########################
# 4A. Evaluation Metrics (unchanged from your original, just consolidated)
##########################

def _levenshtein_distance(ref, hyp):
    """[No changes, same as original internal function]"""
    m = len(ref)
    n = len(hyp)
    if ref == hyp:
        return 0
    if m == 0:
        return n
    if n == 0:
        return m
    if m < n:
        ref, hyp = hyp, ref
        m, n = n, m
    distance = np.zeros((2, n + 1), dtype=np.int32)
    for j in range(0, n + 1):
        distance[0][j] = j
    for i in range(1, m + 1):
        prev_row_idx = (i - 1) % 2
        cur_row_idx = i % 2
        distance[cur_row_idx][0] = i
        for j in range(1, n + 1):
            if ref[i - 1] == hyp[j - 1]:
                distance[cur_row_idx][j] = distance[prev_row_idx][j - 1]
            else:
                s_num = distance[prev_row_idx][j - 1] + 1
                i_num = distance[cur_row_idx][j - 1] + 1
                d_num = distance[prev_row_idx][j] + 1
                distance[cur_row_idx][j] = min(s_num, i_num, d_num)
    return distance[m % 2][n]

def word_errors(reference, hypothesis, ignore_case=False, delimiter=' '):
    """[No changes, same as original]"""
    if ignore_case:
        reference = reference.lower()
        hypothesis = hypothesis.lower()
    ref_words = reference.split(delimiter)
    hyp_words = hypothesis.split(delimiter)
    edit_distance = _levenshtein_distance(ref_words, hyp_words)
    return float(edit_distance), len(ref_words)

def char_errors(reference, hypothesis, ignore_case=False, remove_space=False):
    """[No changes, same as original]"""
    if ignore_case:
        reference = reference.lower()
        hypothesis = hypothesis.lower()
    join_char = ' '
    if remove_space:
        join_char = ''
    reference = join_char.join(filter(None, reference.split(' ')))
    hypothesis = join_char.join(filter(None, hypothesis.split(' ')))
    edit_distance = _levenshtein_distance(reference, hypothesis)
    return float(edit_distance), len(reference)

def wer(reference, hypothesis, ignore_case=False, delimiter=' '):
    """[No changes, same as original]"""
    edit_distance, ref_len = word_errors(reference, hypothesis, ignore_case, delimiter)
    if ref_len == 0:
        raise ValueError("Reference's word number should be greater than 0.")
    return float(edit_distance) / ref_len

def cer(reference, hypothesis, ignore_case=False, remove_space=False):
    """[No changes, same as original]"""
    edit_distance, ref_len = char_errors(reference, hypothesis, ignore_case, remove_space)
    if ref_len == 0:
        raise ValueError("Length of reference should be greater than 0.")
    return float(edit_distance) / ref_len

def levenshtein_distance(s1, s2):
    """[No changes, same as original]"""
    if len(s1) < len(s2):
        return levenshtein_distance(s2, s1)
    if len(s2) == 0:
        return len(s1)
    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    return previous_row[-1]


##########################
# 4B. GreedyDecoder
##########################

def GreedyDecoder(output, labels, label_lengths, text_transform, blank_label=28, collapse_repeated=True):
    """
    Slightly updated to handle when 'labels' might be None (in test mode).
    """
    arg_maxes = torch.argmax(output, dim=2)
    decodes = []
    targets = []

    # If we do have labels, decode them
    if labels is not None and label_lengths is not None:
        for i, args in enumerate(arg_maxes):
            decode = []
            true_text = text_transform.int_to_text(labels[i][:label_lengths[i]].tolist())
            targets.append(true_text)

            for j, index in enumerate(args):
                if index != blank_label:
                    if collapse_repeated and j != 0 and index == args[j-1]:
                        continue
                    decode.append(index.item())
            decodes.append(text_transform.int_to_text(decode))
    else:
        # Test case scenario: no ground truth
        for i, args in enumerate(arg_maxes):
            decode = []
            for j, index in enumerate(args):
                if index != blank_label:
                    if collapse_repeated and j != 0 and index == args[j-1]:
                        continue
                    decode.append(index.item())
            decodes.append(text_transform.int_to_text(decode))

    return decodes, targets


##########################
# 5. Inference (No major changes)
##########################

def infer(model, device, audio_path, text_transform):
    model.eval()
    waveform, sample_rate = torchaudio.load(audio_path)
    spec = valid_audio_transforms(waveform).squeeze(0).transpose(0, 1)
    spec = spec.unsqueeze(0).unsqueeze(1).transpose(2, 3).to(device)  # (1,1,n_mels,time)
    with torch.no_grad():
        output = model(spec)
        output = F.log_softmax(output, dim=2).transpose(0, 1)
        decoded_preds, _ = GreedyDecoder(output.transpose(0, 1), None, None, text_transform, blank_label=text_transform.blank_label)
    return decoded_preds[0]


##########################
# 6. IterMeter, get_device
##########################

class IterMeter(object):
    """Keeps track of total iterations."""
    def __init__(self):
        self.val = 0
    def step(self):
        self.val += 1
    def get(self):
        return self.val

def get_device(use_tpu=False):
    """
    Selects the appropriate device (CPU, GPU, or TPU) based on availability and the `use_tpu` flag.
    [Same logic as your original code, no changes].
    """
    if use_tpu:
        try:
            import torch_xla
            import torch_xla.core.xla_model as xm
            device = xm.xla_device()
            print(f"Using TPU device: {device}")
            return device
        except ImportError:
            print("TPU not found. Using GPU or CPU instead.")
    if torch.cuda.is_available():
        device = torch.device("cuda")
        print(f"Using GPU device: {device}")
    else:
        device = torch.device("cpu")
        print(f"Using CPU device: {device}")
    return device


##########################
# 7. Main
##########################

def main():
    # Hyperparameters
    learning_rate = 5e-4
    batch_size = 2  # start small on memory-limited environment
    epochs = 1    # may adjust for real training
    data_path = "/content/unzipped_files/kaldi-taiwanese-asr"
    lexicon_path = os.path.join(data_path, "lexicon.txt")
    use_tpu = False

    # Select device
    device = get_device(use_tpu)

    # Build the text transform with the lexicon
    text_transform = TextTransform(lexicon_path)

    # We assume n_class = size of phoneme_map. The 'blank_label' is the max index used by the model's CTC
    n_class = len(text_transform.phoneme_map)
    print("Total unique phonemes in lexicon:", n_class)
    print("Blank label index:", text_transform.blank_label)

    hparams = {
        "n_cnn_layers": 3,
        "n_rnn_layers": 5,
        "rnn_dim": 512,
        "n_class": n_class,
        "n_feats": 128,
        "stride": 2,
        "dropout": 0.1,
        "learning_rate": learning_rate,
        "batch_size": batch_size,
        "epochs": epochs
    }

    # Read the main CSV
    csv_path = os.path.join(data_path, 'train-toneless.csv')
    data_df = pd.read_csv(csv_path)

    # Create train/valid/test splits
    train_df, temp_df = train_test_split(data_df, test_size=0.2, random_state=7)
    valid_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=7)

    # Build Datasets
    train_dataset = TaiwaneseDataset(
        train_df, data_path, text_transform,
        audio_transforms=train_audio_transforms,
        subset='train'
    )
    valid_dataset = TaiwaneseDataset(
        valid_df, data_path, text_transform,
        audio_transforms=valid_audio_transforms,
        subset='train'
    )
    # If you have a separate test folder with 346 files (no transcripts):
    # test_dataset = TaiwaneseDataset(test_df, data_path, text_transform,
    #                                 audio_transforms=valid_audio_transforms,
    #                                 subset='test')

    # Build DataLoaders
    train_loader = data.DataLoader(
        dataset=train_dataset,
        batch_size=hparams['batch_size'],
        shuffle=True,
        collate_fn=taiwanese_collate_fn,
        pin_memory=True
    )

    valid_loader = data.DataLoader(
        dataset=valid_dataset,
        batch_size=hparams['batch_size'],
        shuffle=False,
        collate_fn=taiwanese_collate_fn,
        pin_memory=True
    )

    # If you do have a separate test set:
    # test_loader = data.DataLoader(
    #     dataset=test_dataset,
    #     batch_size=hparams['batch_size'],
    #     shuffle=False,
    #     collate_fn=taiwanese_collate_fn,
    #     pin_memory=True
    # )

    # Instantiate model
    model = SpeechRecognitionModel(
        n_cnn_layers=hparams['n_cnn_layers'],
        n_rnn_layers=hparams['n_rnn_layers'],
        rnn_dim=hparams['rnn_dim'],
        n_class=hparams['n_class'],
        n_feats=hparams['n_feats'],
        stride=hparams['stride'],
        dropout=hparams['dropout']
    ).to(device)

    print(model)
    print('Num Model Parameters', sum([param.nelement() for param in model.parameters()]))

    optimizer = optim.AdamW(model.parameters(), hparams['learning_rate'])
    criterion = nn.CTCLoss(blank=text_transform.blank_label).to(device)

    # OneCycleLR for scheduling
    scheduler = optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=hparams['learning_rate'],
        steps_per_epoch=len(train_loader),
        epochs=hparams['epochs'],
        anneal_strategy='linear'
    )

    iter_meter = IterMeter()

    # Training loop
    for epoch in range(1, epochs + 1):
        train(model, device, train_loader, criterion, optimizer, scheduler, epoch, iter_meter)
        validate(model, device, valid_loader, criterion, iter_meter, text_transform)

    ###################
    # 8. Generate Predictions for Kaggle (test set)
    ###################
    # If you want to produce a submission using the "test" folder that has 346 .wav files:
    # You can skip reading a CSV if the test folder has no transcripts:
    test_folder = os.path.join(data_path, 'test')
    test_files = [f for f in os.listdir(test_folder) if f.endswith('.wav')]

    # Instead of using DataFrame.append, create a list for all predictions
    predictions = []

    model.eval()
    for test_file in test_files:
        file_id = test_file.split('.')[0]
        audio_path = os.path.join(test_folder, test_file)

        # Predict
        prediction = infer(model, device, audio_path, text_transform)

        # Collect your results in a list
        predictions.append({
            'id': file_id,
            'text': prediction
        })

    # Convert list of dicts to DataFrame once at the end
    results_df = pd.DataFrame(predictions)
    results_df.to_csv('submission.csv', index=False)


if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:584: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (128) may be set too high. Or, the value for `n_freqs` (201) may be set too low.
#   warnings.warn(
# Using GPU device: cuda
# Total unique phonemes in lexicon: 805
# Blank label index: 804
# SpeechRecognitionModel(
#   (cnn): Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (rescnn_layers): Sequential(
#     (0): ResidualCNN(
#       (cnn1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cnn2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (dropout2): Dropout(p=0.1, inplace=False)
#       (layer_norm1): CNNLayerNorm(
#         (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (layer_norm2): CNNLayerNorm(
#         (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (1): ResidualCNN(
#       (cnn1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cnn2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (dropout2): Dropout(p=0.1, inplace=False)
#       (layer_norm1): CNNLayerNorm(
#         (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (layer_norm2): CNNLayerNorm(
#         (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (2): ResidualCNN(
#       (cnn1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cnn2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (dropout2): Dropout(p=0.1, inplace=False)
#       (layer_norm1): CNNLayerNorm(
#         (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#       (layer_norm2): CNNLayerNorm(
#         (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (fully_connected): Linear(in_features=2048, out_features=512, bias=True)
#   (birnn_layers): Sequential(
#     (0): BidirectionalGRU(
#       (BiGRU): GRU(512, 512, batch_first=True, bidirectional=True)
#       (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (1): BidirectionalGRU(
#       (BiGRU): GRU(1024, 512, bidirectional=True)
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (2): BidirectionalGRU(
#       (BiGRU): GRU(1024, 512, bidirectional=True)
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (3): BidirectionalGRU(
#       (BiGRU): GRU(1024, 512, bidirectional=True)
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (4): BidirectionalGRU(
#       (BiGRU): GRU(1024, 512, bidirectional=True)
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): GELU(approximate='none')
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=512, out_features=805, bias=True)
#   )
# )
# Num Model Parameters 24103461
# Train Epoch: 1 [2/2495 (0%)]	Loss: 126.215393
# Train Epoch: 1 [202/2495 (8%)]	Loss: 6.096183
# Train Epoch: 1 [402/2495 (16%)]	Loss: 5.564465
# Train Epoch: 1 [602/2495 (24%)]	Loss: 6.083608
# Train Epoch: 1 [802/2495 (32%)]	Loss: 5.496075
# Train Epoch: 1 [1002/2495 (40%)]	Loss: 5.816462
# Train Epoch: 1 [1202/2495 (48%)]	Loss: 5.442180
# Train Epoch: 1 [1402/2495 (56%)]	Loss: 6.254745
# Train Epoch: 1 [1602/2495 (64%)]	Loss: 5.721495
# Train Epoch: 1 [1802/2495 (72%)]	Loss: 5.607565
# Train Epoch: 1 [2002/2495 (80%)]	Loss: 6.574665
# Train Epoch: 1 [2202/2495 (88%)]	Loss: 6.056567
# Train Epoch: 1 [2402/2495 (96%)]	Loss: 6.659155
# Train Epoch: 1 [1248/2495 (100%)]	Loss: 6.882181
# Validation set: Average loss: 5.8949, Average WER: 0.9968, Average Levenshtein Distance: 59.2147
